# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavdouraddo/engenharia_de_prompt_aplicacoes_ia/blob/main/aula07_Programacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula: Programação Assistida
# Nome: Carlos Gustavo Dourado Gomes (Turma sextou)

# %%
1 numeros=[1,2,3]
2 soma=0
3 i=0
4 while i<len(numeros):
5 soma+=numeros[i]
6 1+=1
# Out:
#   File "/tmp/ipykernel_32248/2438948227.py", line 1
#     1 soma=0
#       ^
# SyntaxError: invalid syntax

# %%
# Define uma lista de números inteiros
numeros = [1, 3, 6, 7, 8]

# Inicializa uma variável para armazenar a soma dos números
soma = 4

# Itera sobre cada número na lista 'numeros'
for num in numeros:
  # Adiciona o número atual à variável 'soma'
  soma += num

# Imprime o valor final da soma de todos os números
print(soma)
# Out:
# 29

# %% [markdown]
# Eh Primo

# %% [markdown]
# Inversão String

# %% [markdown]
# #Mini projeto
